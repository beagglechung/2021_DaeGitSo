# %%
from tkinter import *

window = Tk()

window.mainloop()

# %%
from tkinter import *

window = Tk()

label = Label(window, text="Hello World")
label.pack()

window.mainloop()

# %%
from tkinter import *

window = Tk()

label = Label(window, text="이것이 파이썬 버튼입니다")
label.pack()

window.mainloop()

# %%
#389 배치관리 소개 -1 
from tkinter import *

window = Tk()
b1 = Button(window, text="첫번째 버튼")
b2 = Button(window, text="두번째 버튼")
b1.pack()
b2.pack()

window.mainloop()

# %%
#389 배치관리 소개 -2
from tkinter import *

window = Tk()
b1 = Button(window, text="첫번째 버튼")
b2 = Button(window, text="두번째 버튼")
b1.pack(side=LEFT)
b2.pack(side=LEFT)

window.mainloop()

# %%
#389 배치관리 소개 -3
from tkinter import *

window = Tk()
b1 = Button(window, text="첫번째 버튼")
b2 = Button(window, text="두번째 버튼")
b1.pack(side=LEFT, padx=10)
b2.pack(side=LEFT, padx=10)

window.mainloop()

# %%
#390
from tkinter import *

def callback() :
    button["text"]="버튼이 클릭되었음"
    
window = Tk()
button = Button(window, text="클릭", command=callback)
button.pack(side=LEFT)

window.mainloop()

# %%
#391
from tkinter import *
 
window = Tk()

label = Label(window, text="안녕하세요")
label.pack()

button = Button(window, text="tkinter로 버튼을 쉽게 만들수 있습니다.")
button.pack()

window.mainloop()

# %%
#392 클래스로 프레임 감싸기
from tkinter import *

def hello():
    print("Hello 버튼")
    
def quit():
    print("Quit 버튼")
    
window = Tk()
helloB = Button(window, text="Hello", command=hello, fg="red")
helloB.pack(side=LEFT)

quitB = Button(window, text="Quit", command=quit)
quitB.pack(side=LEFT)
window.mainloop()
# Out:
# Hello 버튼
# Quit 버튼

# %%
#392 클래스로 프레임 감싸기
from tkinter import *

class APP:
    def __init__(self):
        window = Tk()
        helloB = Button(window, text="Hello", command=hello, fg="red")
        helloB.pack(side=LEFT)

        quitB = Button(window, text="Quit", command=quit)
        quitB.pack(side=LEFT)
        window.mainloop()
        
def hello():
    print("Hello 버튼")
    
def quit():
    print("Quit 버튼")
    
App()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d22f841cdfd7> in <module>()
#      18     print("Quit 버튼")
#      19
# ---> 20 App()
#
# NameError: name 'App' is not defined

# %%
#392 클래스로 프레임 감싸기
from tkinter import *
window = Tk()

button = Button(window, text="버튼을 클릭하세요")
button.pack()
button["fg"] = "yellow"
button["bg"] = "green"

window.mainloop()

# %%
#398

from tkinter import *
from tkinter.colorchooser import *

color = colorchooser.askcolor()
print(color)
# Out:
# ((90.3515625, 129.50390625, 231.90234375), '#5a81e7')

# %%
#400
import tkinter as tk
import tkinter.font as font

def BigFont():
    size = customFont['size']
    customFont.configure(size=size+2)
        
def SmallFont():
    size = customFont['size']
    customFont.configure(size=size-2)

        
root = tk.Tk()
       
customFont = font.Font(family="Helvetica", size=12)
        
buttonframe = tk.Frame()
label = tk.Label(root,text="Hello, World", font=customFont)
buttonframe.pack()
label.pack()
        
bigger = tk.Button(root, text="폰트를 크게", command=BigFont)
smaller = tk.Button(root, text="폰트를 작게", command=SmallFont)
bigger.pack()
smaller.pack()
        
root.mainloop()

# %%
#400 클래스
import tkinter as tk
import tkinter.font as font

class App:
    def __init__(selt):
        root=tk.Tk()
        
        self.customFont = font.Font(family="Helvetica", size=12)
        
        buttonframe=tk.Frame()
        label = tk.Label(root,text="Hello, World", font=self.customFont)
        buttonfrme.pack()
        label.pack()
        
        bigger = tk.Button(root, text="폰트를 크게", command=self.BigFont)
        smaller = tk.Button(root, text="폰트를 작게", command=self.SmallFont)
        bigger.pack()
        smaller.pack()
        
        root.mainloop()
        
    def BigFont(self):
        size = self.customFont['size']
        self.customFont.configure(size=size+2)
        
    def SmallFont(self):
        size = self.customFont['size']
        self.customFont.configure(size=size-2)
        
app=APP()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a86d6b39114e> in <module>()
#      29         self.customFont.configure(size=size-2)
#      30
# ---> 31 app=APP()
#
# NameError: name 'APP' is not defined

# %%
#401 레이블. 이미지

from tkinter import *

window = Tk()
photo = PhotoImage(file="sun2.gif")



w = Label(window, image=photo)
w.photo = photo
w.pack()



window.mainloop()

# %%
#401 레이블에 이미지와 텍스트를 동시에 나타내기

from tkinter import *

window = Tk()
photo = PhotoImage(file="ai.gif")


w = Label(window, image=photo).pack(side="right") #이미지정의

message = """삶이 그대를 속일지라도 
슬퍼하거나 노하지 말라!"""


w2 = Label(window, #텍스트정의
          justify=LEFT,
          padx=10,
          text=message).pack(side="left")

window.mainloop()

# %%
#402 레이블의 색상과 폰트 변경하기
from tkinter import *

window = Tk()

Label(window, 
     text = "Times Font 폰트와 빨강색을 사용합니다.",
     fg = "red",
     font = "Times 32 bold italic").pack()

Label(window, 
      text = "Helvetica 폰트와 초록색을 사용합니다.",
      fg = "green",
      bg = "Yellow",
      font = "Belvetica 32 bold italic").pack()

window.mainloop()

# %%
#404 텍스트 입력
from tkinter import *

window = Tk()
Label(window, text="이름").grid(row=0)
Label(window, text="나이").grid(row=1)

e1 = Entry(window)
e2 = Entry(window)

e1.grid(row=0, column=1)
e2.grid(row=1, column=1)

window.mainloop()

# %%
#404 텍스트 입력
from tkinter import *

def show() :
    print("이름: %s\n나이: %s" % (e1.get(), e2.get())) #get()으로 엔트리의 내용을 가져옴
   
parent = Tk()
Label(parent, text="이름").grid(row=0)
Label(parent, text="나이").grid(row=1)

e1 = Entry(parent)
e2 = Entry(parent)

e1.grid(row=0, column=1)
e2.grid(row=1, column=1)

Button(parent, text="종료", command=parent.quit).grid(row=3, column=0, sticky=W, pady=4)
Button(parent, text="보이기", command=show).grid(row=3, column=1, sticky=W, pady=4)


parent.mainloop()
# Out:
# 이름: we
# 나이: 324

# %%
#407 계산기
from tkinter import *
from math import *

def calculate(event):
    label.configure(text="결과: " + str(eval(entry.get())))

window = Tk()
Label(window, text="파이썬 수식 입력").pack()

entry = Entry(window)
entry.bind("<Return>", calculate) #엔트리 위젯에서 엔터키를 치면 calculate()가 호출
entry.pack()
label = Label(window, text="결과: ")
label.pack()

window.mainloop()

# %%
#408 캔버스 생성
from tkinter import *

window = Tk()
w = Canvas(window, width=300, height=200)
w.pack()

w.create_line(0, 0, 300, 200)
w.create_line(0, 0, 300, 100, fill="red")
w.create_rectangle(50, 25, 200, 100, fill="blue")

window.mainloop()

# %%
#409 캔버스 그림그리기
from tkinter import *

window = Tk()
w = Canvas(window, width=300, height=200)
w.pack()

i = w.create_line(0, 0, 300, 200, fill="red")
w.coords(i, 0, 0, 300, 100) #좌표를 변경
w.itemconfig(i, fill="blue") #색상을 변경

#w.delete(i)
w.delete(ALL)
window.mainloop()

# %%
#411 색상 설정하기
from tkinter import *

window = Tk()
w = Canvas(window, width=300, height=200)
w.pack()

w.create_rectangle(50, 25, 200, 100, outline="blue")

window.mainloop()

# %%
#413 색상을 사용자로부터 입력받기
from tkinter import *
from tkinter.colorchooser import * #교재게 없는 내용 추가

window = Tk()
w = Canvas(window, width=300, height=200)
w.pack()
color = colorchooser.askcolor()

w.create_rectangle(50, 25, 200, 100, fill=color[1])

window.mainloop()

# %%
#415 랜덤한 사각형 그리기
import random
from tkinter import *

window = Tk()
canvas = Canvas(window, width=500, height=400)
canvas.pack()
color = ["red","orange","yellow","green","blue","violet"]

def draw_rect():
    x=random.randint(0,500)
    y=random.randint(0,400)
    w=random.randrange(100)
    h=random.randrange(100)
    canvas.create_rectangle(x,y,w,h, fill=random.choice(color))
    
for i in range(10):
    draw_rect()
    
window.mainloop()

# %%
#417 타원그리기
from tkinter import *

window = Tk()
canvas = Canvas(window, width=300, height=200)
canvas.pack()
canvas.create_oval(10,10,200,150)

window.mainloop()

# %%
#417 호그리기
from tkinter import *

window = Tk()
canvas = Canvas(window, width=300, height=200)
canvas.pack()
canvas.create_arc(10, 10, 200, 150, extent=90, style=ARC)

window.mainloop()

# %%
#418 (반복해서) 호그리기
from tkinter import *

window = Tk()
canvas = Canvas(window, width=300, height=200)
canvas.pack()

for degree in range(0, 360, 30) :
    canvas.create_arc(10, 10+degree//5, 200, 150+degree//5, extent=degree, style=ARC)

window.mainloop()

# %%
#419 다각형 그리기
from tkinter import *

window = Tk()
canvas = Canvas(window, width=300, height=200)
canvas.pack()

canvas.create_polygon(10, 10, 150, 110, 250, 20, fill="blue")

window.mainloop()

# %%
#419 다각형 그리기-2
from tkinter import *

window = Tk()
canvas = Canvas(window, width=300, height=200)
canvas.pack()

points=[0,0,80,150,250,20]
canvas.create_polygon(points, outline="red",
                     fill="yellow", width=5)

window.mainloop()

# %%
#420 텍스트 그리기
from tkinter import *

window = Tk()
canvas = Canvas(window, width=300, height=200)
canvas.pack()

canvas.create_text(100,100,text='싱 스트리트(Sing Street)')

window.mainloop()

# %%
#421 텍스트 그리기-2
from tkinter import *

window = Tk()
canvas = Canvas(window, width=300, height=200)
canvas.pack()

canvas.create_text(250,10,text='싱 스트리트(Sing Street)', fill="blue", font=('courier',20))
canvas.create_text(250,100,text='싱 스트리트(Sing Street)', fill="red", font=('Hevetica',30))
canvas.create_text(250,150,text='싱 스트리트(Sing Street)', fill="blue", font=('courier',40))

window.mainloop()

# %%
#421 이미지 표시하기
from tkinter import *

window = Tk()
canvas = Canvas(window, width=300, height=300)
canvas.pack()

img = PhotoImage(file="ai.gif")
canvas.create_image(20, 20, anchor=NW, image=img) #anchor=NU (NW:NorthWest)

window.mainloop()

# %%
#423 애니메이션을 만들어보자
from tkinter import *
import time

window = Tk()
canvas = Canvas(window, width=300, height=300)
canvas.pack()

id=canvas.create_oval(10, 100, 50, 150, fill="green")

for i in range(100):
    canvas.move(id, 3, 0)
    window.update()
    time.sleep(0.05)

window.mainloop()

# %%
#423 애니메이션을 만들어보자-2
from tkinter import *
import time

window = Tk()
canvas = Canvas(window, width=300, height=300)
canvas.pack()

id=canvas.create_oval(10, 100, 50, 150, fill="green")

for i in range(100):
    canvas.move(id, 3, 2)
    window.update()
    time.sleep(0.05)

window.mainloop()

# %%
#425 화살표 키로 공을 움직여 보자.
from tkinter import *

window = Tk()
canvas = Canvas(window, width=400, height=300)
canvas.pack()

id=canvas.create_oval(10, 100, 50, 150, fill="green")

def move_right(event):
    canvas.move(id,5,0)

canvas.bind_all('<KeyPress-Right>', move_right)
    
window.mainloop()

# %%
#425 화살표 키로 공을 움직여 보자.-2
from tkinter import *

window = Tk()
canvas = Canvas(window, width=400, height=300)
canvas.pack()

id=canvas.create_oval(10, 100, 50, 150, fill="green")

def move_right(event):
    canvas.move(id,5,0)

def move_left(event):
    canvas.move(id,-5,0)
    
canvas.bind_all('<KeyPress-Right>', move_right)
canvas.bind_all('<KeyPress-Left>', move_left)
    
window.mainloop()

# %%
#427 마우스로 그림 그리기
from tkinter import *

w = 500
h = 300

def drawDot(event):
    x1,y1 = (event.x-1), (event.y-1)
    x2,y2 = (event.x+1), (event.y+1)
    canvas.create_oval(x1, y1, x2, y2, fill="red")
    
window = Tk()
canvas = Canvas(window, width=w, height=h)
canvas.pack(expand=YES, fill=BOTH)
canvas.bind("<B1-Motion>", drawDot)

message = Label(window, text="마우스를 드래그하면 점들이 그려집니다")
message.pack(side=BOTTOM)

window.mainloop()

# %%
#429 라디오버튼-1
from tkinter import *

window = Tk()
choice = IntVar()

Label(window,
     text="가장 선호하는 프로그래밍 언어를 선택하시오",
     justify=LEFT,
     padx=20).pack()

Radiobutton(window, text="Python", padx=20, variable=choice, value=1).pack(anchor=W)
Radiobutton(window, text="C",      padx=20, variable=choice, value=2).pack(anchor=W)
Radiobutton(window, text="Java",   padx=20, variable=choice, value=3).pack(anchor=W)
Radiobutton(window, text="Swift",  padx=20, variable=choice, value=4).pack(anchor=W)

window.mainloop()

# %%
#429 라디오버튼-2
from tkinter import *

window = Tk()

select = IntVar()
select.set(1)

list = [("Python",1), ("C",2), ("Java",3), ("Swift",4),]

def PrintChoice() :
    print(select.get())

Label(window, text="가장 선호하는 프로그래밍 언어를 선택하시오",
     justify = LEFT,
     padx = 20).pack()

for txt, val in list :
    Radiobutton(window, 
               text=txt,
               variable=select,
               command=PrintChoice,
               value=val).pack(anchor=W)

window.mainloop()
# Out:
# 2
# 3
# 4
# 1

# %%
#431 체크 박스
from tkinter import *

window = Tk()
Label(window, text="선호하는 언어를 모두 선택하시오:").grid(row=0, sticky=W) # sticky 정렬(E,W, N, S)

value1 = IntVar()
Checkbutton(window, text="Python", variable=value1).grid(row=1, sticky=W)
value2 = IntVar()
Checkbutton(window, text="C", variable=value2).grid(row=2, sticky=W)
value3 = IntVar()
Checkbutton(window, text="Java", variable=value3).grid(row=3, sticky=W)
value4 = IntVar()
Checkbutton(window, text="Swift", variable=value4).grid(row=4, sticky=W)

window.mainloop()

# %%
#432 리스트 박스 위젯
from tkinter import *

window = Tk()

lb = Listbox(window, height=4) # 라인수
lb.pack()
lb.insert(END,"Python")
lb.insert(END,"C")
lb.insert(END,"Java")
lb.insert(END,"Swift")

window.mainloop()

# %%
#432 리스트 박스 위젯
from tkinter import *

window = Tk()

#스크롤바 추가
sb = Scrollbar(window, orient=VERTICAL)
sb.pack(side=RIGHT, fill=Y)

lb = Listbox(window, height=4) # 라인수
lb.pack()
lb.insert(END,"Python")
lb.insert(END,"C")
lb.insert(END,"Java")
lb.insert(END,"Swift")
lb.insert(END,"Go")
lb.insert(END,"C++")
lb.insert(END,"C#")

window.mainloop()

# %%
#435 격자 배치 관리자
from tkinter import *
window = Tk()

b1 = Button(window, text="One")
b2 = Button(window, text="Two")

b1.grid(row=0, column=0)
b2.grid(row=1, column=1)

window.mainloop()

# %%
#435 격자 배치 관리자-2
from tkinter import *
window = Tk()

b1 = Button(window, text="One")
b2 = Button(window, text="Two")

b1.grid(row=0, column=0)
b2.grid(row=1, column=1)

l = Label(window, text="이것은 레이블입니다.")
l.grid(row=1, column=0)

window.mainloop()

# %%
#435 압축 배치 관리자
from tkinter import *

window = Tk()

Label(window, text="박스 #1", bg="red", fg="white").pack()
Label(window, text="박스 #2", bg="green", fg="black").pack()
Label(window, text="박스 #3", bg="blue", fg="white").pack()

window.mainloop()

# %%
#436 압축 배치 관리자-2 fill 옵션 사용, x방향으로 채우기
from tkinter import *

window = Tk()

Label(window, text="박스 #1", bg="red", fg="white").pack(fill=X)
Label(window, text="박스 #2", bg="green", fg="black").pack(fill=X)
Label(window, text="박스 #3", bg="blue", fg="white").pack(fill=X)

window.mainloop()

# %%
#436 압축 배치 관리자-3 왼쪽에서 오른쪽으로 배치
from tkinter import *

window = Tk()

Label(window, text="박스 #1", bg="red", fg="white").pack(padx=5, pady=0, side=LEFT)
Label(window, text="박스 #2", bg="green", fg="black").pack(padx=5, pady=0, side=LEFT)
Label(window, text="박스 #3", bg="blue", fg="white").pack(padx=5, pady=0, side=LEFT)

window.mainloop()

# %%
#436 절대 위치 배치 관리자
from tkinter import *

window = Tk()

w = Label(window, text="박스 #1", bg="red", fg="white")
w.place(x=0, y=0)
w = Label(window, text="박스 #2", bg="green", fg="black")
w.place(x=20, y=20)
w = Label(window, text="박스 #3", bg="blue", fg="white")
w.place(x=40, y=40)

window.mainloop()

# %%
#437 여러 배치 관리자 혼용
from tkinter import *

window = Tk()
f = Frame(window)

b1 = Button(f, text="One")
b2 = Button(f, text="Two")
b3 = Button(f, text="Three")

b1.pack(side=LEFT)
b2.pack(side=LEFT)
b3.pack(side=LEFT)

l = Label(window, text="이 레이블은 버튼 위에 배치된다.")
l.pack() #레이블이 윈도우 상단에 배치된다.
f.pack() #프레임이 수직으로 쌓이게 된다.

window.mainloop()

# %%
#438 TIC-TAC-TOE 게임
from tkinter import *

# i번째 버튼을 누를 수 있는지 검사한다. 누를 수 있으면 X나 O를 표시한다. 
def checked(i):
    global player
    button = list[i] # 리스트에서 I번째 버튼 객체를 가져온다. 

# 버튼이 초기상태가 아니면 이미 누른 버튼이므로 아무것도 하지 않고 리턴한다.
    if button["text"] != "            ":
        return
    button["text"] = "     " + player+"      "
    button["bg"] = "yellow"
    
    if player=="X":
        player = "O"
        button["bg"] = "yellow"
    else :
        player = "X"
        button["bg"] = "lightgreen"


window = Tk() # 윈도우를 생성한다.  
player="X" # 시작은 플레이어 X이다. 
list = []

# 9개의 버튼을 생성하여 격자 형태로 윈도우에 배치한다. 
for i in range(9):
    b = Button(window, text="            ", command=lambda k=i: checked(k))
    b.grid(row=i//3, column=i%3)
    list.append(b)	# 버튼 객체를 리스트에 저장한다. 

window.mainloop()

# %%
#441 배치 관리자 사용하기
from tkinter import *

window = Tk()
colors = ['green', 'red', 'orange','white','yellow','blue']

r = 0
for c in colors:
    Label(window, text=c, relief=RIDGE, width=15).grid(row=r, column=0)
    Button(window, bg=c, width=10).grid(row=r, column=1)
    r = r + 1

window.mainloop()

# %%
#443 스톱위치 만들기
import tkinter as tk

def startTimer():
    if (running):
        global timer #전역 변수 timer를 사용
        timer += 1
        timeText.configure(text=str(timer))
    window.after(10, startTimer) #10ms 후에 startTimer()가 호출되도록 함

def start():
    global running
    running = True

def stop():
    global running
    running = False

running = False

window = tk.Tk()

timer = 0

timeText = tk.Label(window, text="0", font=("Helvetica", 80))
timeText.pack()

startButton = tk.Button(window, text='시작', bg="yellow", command=start)
startButton.pack(fill=tk.BOTH)

stopButton = tk.Button(window, text='중지', bg="yellow", command=stop)
stopButton.pack(fill=tk.BOTH)

startTimer()
window.mainloop()

# %%
#444 계산기 만들기
from tkinter import *

def click(key):
    if key == '=':		# “=” 버튼이면 수식을 계산하여 결과를 표시한다.
        try:
            result = eval(entry.get())
            entry.delete(0, END) 
            entry.insert(END, str(result))
        except:
            entry.insert(END, "오류!")
    elif key == 'C':
        entry.delete(0, END) 
    else:
        entry.insert(END, key)

window = Tk()
window.title("간단한 계산기")

buttons = [
'7',  '8',  '9',  '+',  'C',
'4',  '5',  '6',  '-',  '  ',
'1',  '2',  '3',  '*',  '  ',
'0',  '.',  '=',  '/',  '   ' ]

# 반복문으로 버튼을 생성한다.
i=0
for b in buttons:
    cmd = lambda x=b: click(x)
    b = Button(window,text=b,width=5,relief='ridge',command=cmd)
    b.grid(row=i//5+1,column=i%5)
    i += 1

# 엔트리 위젯은 맨 윗줄의 5개의 셀에 걸쳐서 배치된다. 
entry = Entry(window, width=33, bg="yellow")
entry.grid(row=0, column=0, columnspan=5)

window.mainloop()

# %%
#446 마우스 이벤트 처리

window = Tk()

def callback(event):
    print(event.x, event.y, "에서 마우스 이벤트 발생")

frame = Frame(window, width=100, height=100)

frame.bind("<Button-1>", callback) 
frame.pack()

window.mainloop()
# Out:
# 83 59 에서 마우스 이벤트 발생
# 81 41 에서 마우스 이벤트 발생
# 0 8 에서 마우스 이벤트 발생
# 2 39 에서 마우스 이벤트 발생

# %%
#447 키보드 이벤트 처리

from tkinter import *

window = Tk()

def key(event):
    print ( repr(event.char), "가 눌렸습니다. ")
#repr() 문자코드를 문자열로 변환

def callback(event):
    frame.focus_set()
    print(event.x, event.y, "에서 마우스 이벤트 발생")

frame = Frame(window, width=100, height=100)
frame.bind("<Key>", key)
frame.bind("<Button-1>", callback)
frame.pack()

window.mainloop()
# Out:
# 67 43 에서 마우스 이벤트 발생
# 'd' 가 눌렸습니다.
# 'f' 가 눌렸습니다.
# 'd' 가 눌렸습니다.
# 'f' 가 눌렸습니다.
# 'a' 가 눌렸습니다.
# 'd' 가 눌렸습니다.
# 's' 가 눌렸습니다.
# 'f' 가 눌렸습니다.
# 'd' 가 눌렸습니다.
# 'r' 가 눌렸습니다.
# 'y' 가 눌렸습니다.

# %%
#450 마우스 이벤트 처리
from tkinter import *

def sleft(event):
    print("단일 클릭, 왼쪽 버튼") 
def dleft(event):                           
    print("더블 클릭, 왼쪽 버튼") 

widget = Button(None, text='마우스 클릭')
widget.pack()

widget.bind('<Button-1>', sleft)
widget.bind('<Double-1>', dleft) 

widget.mainloop()
# Out:
# 단일 클릭, 왼쪽 버튼
# 단일 클릭, 왼쪽 버튼
# 더블 클릭, 왼쪽 버튼
# 더블 클릭, 왼쪽 버튼
# 더블 클릭, 왼쪽 버튼
# 더블 클릭, 왼쪽 버튼
# 더블 클릭, 왼쪽 버튼
# 더블 클릭, 왼쪽 버튼
# 더블 클릭, 왼쪽 버튼
# 단일 클릭, 왼쪽 버튼

# %%
#450 마우스 이벤트 처리
from tkinter import *

def motion(event):
  print("마우스 위치: (%s %s)" % (event.x, event.y))
  return

window = Tk()
message = """당신 스스로가 하지 않으면
            아무도 당신의 운명을 
            개선시켜주지 않을 것이다. """

msg = Message(window, text = message)
msg.config(bg='yellow',fg='blue',  font="times 12 italic")
msg.bind('<Motion>',motion)
msg.pack()
window.mainloop()
# Out:
# 마우스 위치: (90 110)
# 마우스 위치: (85 104)
# 마우스 위치: (82 99)
# 마우스 위치: (82 97)
# 마우스 위치: (82 96)
# 마우스 위치: (82 98)
# 마우스 위치: (82 100)
# 마우스 위치: (82 102)
# 마우스 위치: (85 104)
# 마우스 위치: (94 105)
# 마우스 위치: (105 105)
# 마우스 위치: (114 104)
# 마우스 위치: (121 103)
# 마우스 위치: (127 103)
# 마우스 위치: (131 103)
# 마우스 위치: (134 103)
# 마우스 위치: (137 104)
# 마우스 위치: (140 104)
# 마우스 위치: (143 104)
# 마우스 위치: (146 104)
# 마우스 위치: (149 104)
# 마우스 위치: (152 104)
# 마우스 위치: (154 104)
# 마우스 위치: (156 104)
# 마우스 위치: (158 104)
# 마우스 위치: (160 104)
# 마우스 위치: (161 106)
# 마우스 위치: (164 109)
# 마우스 위치: (166 110)
# 마우스 위치: (167 112)
# 마우스 위치: (169 113)
# 마우스 위치: (172 115)
# 마우스 위치: (174 116)
# 마우스 위치: (177 117)
# 마우스 위치: (180 118)
# 마우스 위치: (183 118)
# 마우스 위치: (185 118)
# 마우스 위치: (187 118)
# 마우스 위치: (189 118)
# 마우스 위치: (190 118)
# 마우스 위치: (191 118)
# 마우스 위치: (192 117)
# 마우스 위치: (193 117)
# 마우스 위치: (192 116)
# 마우스 위치: (191 116)
# 마우스 위치: (190 116)
# 마우스 위치: (189 116)
# 마우스 위치: (188 116)
# 마우스 위치: (188 115)
# 마우스 위치: (187 114)
# 마우스 위치: (186 113)
# 마우스 위치: (186 112)
# 마우스 위치: (186 110)
# 마우스 위치: (186 109)
# 마우스 위치: (186 108)
# 마우스 위치: (186 107)
# 마우스 위치: (186 108)
# 마우스 위치: (189 108)
# 마우스 위치: (191 109)
# 마우스 위치: (191 110)
# 마우스 위치: (191 111)
# 마우스 위치: (193 111)
# 마우스 위치: (193 112)
# 마우스 위치: (70 62)
# 마우스 위치: (50 15)
# 마우스 위치: (47 3)
# 마우스 위치: (52 14)
# 마우스 위치: (57 25)
# 마우스 위치: (64 35)
# 마우스 위치: (69 44)
# 마우스 위치: (73 51)
# 마우스 위치: (76 55)
# 마우스 위치: (78 57)
# 마우스 위치: (78 60)
# 마우스 위치: (79 61)
# 마우스 위치: (79 62)
# 마우스 위치: (80 62)
# 마우스 위치: (80 63)
# 마우스 위치: (87 61)
# 마우스 위치: (109 57)
# 마우스 위치: (142 54)
# 마우스 위치: (173 52)

# %%
#숫자 추측 게임
from tkinter import *
import random

answer = random.randint(1,100)

def guessing():
    guess = int(guessField.get())

    if guess > answer:
        msg = "높음!"
    elif guess < answer:
        msg = "낮음!"
    else:
        msg = "정답!"

    resultLabel["text"] = msg
    guessField.delete(0, 5)
    
    def reset():
        global answer
    answer = random.randint(1,100)
    resultLabel["text"] = "다시 한번 하세요!"

window = Tk()
window.configure(bg="white")
window.title("숫자를 맞춰보세요!")
window.geometry("500x80")

titleLabel = Label(window, text="숫자 게임에 오신 것을 환영합니다!", bg="white")
titleLabel.pack()

guessField = Entry(window)
guessField.pack(side="left")
tryButton = Button(window, text="시도", fg="green", bg="white", command=guessing )
tryButton.pack(side="left")

resetButton = Button(window, text="초기화", fg="red", bg="white", command=reset)
resetButton.pack(side="left")
resultLabel = Label(window, text="1부터 100사이의 숫자를 입력하시오.", bg="white") 
resultLabel.pack(side="left")

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-222024d75735> in <module>()
#      36 tryButton.pack(side="left")
#      37
# ---> 38 resetButton = Button(window, text="초기화", fg="red", bg="white", command=reset)
#      39 resetButton.pack(side="left")
#      40 resultLabel = Label(window, text="1부터 100사이의 숫자를 입력하시오.", bg="white")
#
# NameError: name 'reset' is not defined
